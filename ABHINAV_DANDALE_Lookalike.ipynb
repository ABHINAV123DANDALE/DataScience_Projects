# %% [markdown]
# # IMPORTING TO BE USEFUL LIBRARIES

# %%
# importing useful libraries at once
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity

# %%
# importing all provided files at once
customers = pd.read_csv(r"C:\Users\Acer\OneDrive\Desktop\ZEOTAP ASSIGNMENT\Customers (1).csv")
products = pd.read_csv(r"C:\Users\Acer\OneDrive\Desktop\ZEOTAP ASSIGNMENT\Products (1).csv")
transactions = pd.read_csv(r"C:\Users\Acer\OneDrive\Desktop\ZEOTAP ASSIGNMENT\Transactions.csv")

# %%
# merging two files transactions and customers
customers_transactions = pd.merge(customers, transactions, on='CustomerID', how='inner')

# %%
# merging preveosly merged files with remaining file
full_data = pd.merge(customers_transactions, products, on='ProductID', how='inner')

# %%
# renaming all merged data for easier coding
df = full_data

# %%
# removing any signs in column names
customers.columns = customers.columns.str.lower().str.replace(' ', '_')
products.columns = products.columns.str.lower().str.replace(' ', '_')
transactions.columns = transactions.columns.str.lower().str.replace(' ', '_')

# %%
# dropping price_y
df = df.drop(columns=['Price_y'])

# %%
# renaming Price_x
df = df.rename(columns={'Price_x': 'Price'})

# %%
# changing to date time format
df['SignupDate'] = pd.to_datetime(df['SignupDate'])
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       1000 non-null   object
#  1   CustomerName     1000 non-null   object
#  2   Region           1000 non-null   object
#  3   SignupDate       1000 non-null   datetime64[ns]
#  4   TransactionID    1000 non-null   object
#  5   ProductID        1000 non-null   object
#  6   TransactionDate  1000 non-null   datetime64[ns]
#  7   Quantity         1000 non-null   int64
#  8   TotalValue       1000 non-null   float64
#  9   Price            1000 non-null   float64
#  10  ProductName      1000 non-null   object
#  11  Category         1000 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(1), object(7)
# memory usage: 101.6+ KB

# %%
#changing data types 
df['Price'] = df['Price'].astype(int)
df['Quantity'] = df['Quantity'].astype(float)
df['TotalValue'] = df['TotalValue'].astype(float)

# %%
df.head(25)
# Out:
#    CustomerID        CustomerName         Region SignupDate TransactionID  \
# 0       C0001    Lawrence Carroll  South America 2022-07-10        T00015
# 1       C0019   Brandon Rodriguez         Europe 2023-01-12        T00423
# 2       C0038     Jeffrey Perkins  North America 2022-04-16        T00395
# 3       C0039       Angela Harris  South America 2024-10-13        T00053
# 4       C0047      Samantha Frank  North America 2024-03-22        T00784
# 5       C0073       Heidi Johnson         Europe 2022-08-20        T00634
# 6       C0083     Christina Stark  South America 2022-04-07        T00581
# 7       C0086  Stephanie Peterson         Europe 2022-09-18        T00873
# 8       C0124       Lindsay Perez         Europe 2024-08-26        T00203
# 9       C0143        Brian Parker           Asia 2024-05-27        T00262
# 10      C0156       William Adams  North America 2023-08-19        T00699
# 11      C0165       Juan Mcdaniel  South America 2022-04-09        T00210
# 12      C0165       Juan Mcdaniel  South America 2022-04-09        T00327
# 13      C0171       Michael Cowan  South America 2022-12-16        T00884
# 14      C0181    Alexander Barker  South America 2023-11-16        T00926
# 15      C0190      Alexander Lowe  South America 2024-05-31        T00808
# 16      C0001    Lawrence Carroll  South America 2022-07-10        T00932
# 17      C0025        Gregory Odom  South America 2022-07-04        T00509
# 18      C0035  Brianna Richardson  North America 2024-10-01        T00271
# 19      C0065        Gerald Hines  North America 2024-07-10        T00160
# 20      C0097           Tina Ford           Asia 2023-12-18        T00051
# 21      C0104       Laura Bennett  South America 2022-02-10        T00886
# 22      C0121       Mark Atkinson         Europe 2023-07-23        T00895
# 23      C0124       Lindsay Perez         Europe 2024-08-26        T00742
# 24      C0140     Gregory Estrada           Asia 2023-07-01        T00612
#
#    ProductID     TransactionDate  Quantity  TotalValue  Price  \
# 0       P054 2024-01-19 03:12:55       2.0      114.60     57
# 1       P054 2024-11-08 10:22:51       3.0      171.90     57
# 2       P054 2024-03-14 08:10:08       3.0      171.90     57
# 3       P054 2024-09-30 14:42:16       3.0      171.90     57
# 4       P054 2024-08-23 09:06:06       3.0      171.90     57
# 5       P054 2024-03-20 02:37:13       4.0      229.20     57
# 6       P054 2024-11-13 04:56:27       2.0      114.60     57
# 7       P054 2024-08-02 11:13:00       4.0      229.20     57
# 8       P054 2024-03-31 16:50:02       4.0      229.20     57
# 9       P054 2024-01-30 22:40:57       1.0       57.30     57
# 10      P054 2024-04-21 22:39:45       3.0      171.90     57
# 11      P054 2024-08-15 15:59:47       2.0      114.60     57
# 12      P054 2024-11-27 10:42:19       2.0      114.60     57
# 13      P054 2024-01-28 18:40:51       3.0      171.90     57
# 14      P054 2024-08-16 02:29:10       3.0      171.90     57
# 15      P054 2024-07-06 00:13:42       4.0      229.20     57
# 16      P022 2024-09-17 09:01:18       3.0      412.62    137
# 17      P022 2024-08-13 22:51:21       1.0      137.54    137
# 18      P022 2024-04-29 19:45:24       3.0      412.62    137
# 19      P022 2024-07-29 06:59:14       3.0      412.62    137
# 20      P022 2024-03-23 05:58:54       1.0      137.54    137
# 21      P022 2024-10-28 14:36:09       3.0      412.62    137
# 22      P022 2024-05-03 18:35:03       3.0      412.62    137
# 23      P022 2024-03-23 05:53:50       2.0      275.08    137
# 24      P022 2024-10-15 18:21:07       1.0      137.54    137
#
#            ProductName    Category
# 0   SoundWave Cookbook       Books
# 1   SoundWave Cookbook       Books
# 2   SoundWave Cookbook       Books
# 3   SoundWave Cookbook       Books
# 4   SoundWave Cookbook       Books
# 5   SoundWave Cookbook       Books
# 6   SoundWave Cookbook       Books
# 7   SoundWave Cookbook       Books
# 8   SoundWave Cookbook       Books
# 9   SoundWave Cookbook       Books
# 10  SoundWave Cookbook       Books
# 11  SoundWave Cookbook       Books
# 12  SoundWave Cookbook       Books
# 13  SoundWave Cookbook       Books
# 14  SoundWave Cookbook       Books
# 15  SoundWave Cookbook       Books
# 16  HomeSense Wall Art  Home Decor
# 17  HomeSense Wall Art  Home Decor
# 18  HomeSense Wall Art  Home Decor
# 19  HomeSense Wall Art  Home Decor
# 20  HomeSense Wall Art  Home Decor
# 21  HomeSense Wall Art  Home Decor
# 22  HomeSense Wall Art  Home Decor
# 23  HomeSense Wall Art  Home Decor
# 24  HomeSense Wall Art  Home Decor

# %% [markdown]
# # CREATING THE LOOKALIKE

# %%
# Aggregating transaction data by customer
customer_features = df.groupby('CustomerID').agg({
    'TotalValue': 'sum',
    'Quantity': 'sum',
    'Price': 'mean'
}).reset_index()
customer_features = pd.merge(customer_features, df, on='CustomerID', how='inner')

# %%
# Encoding categorical features (e.g., Region)
customer_features_encoded = pd.get_dummies(customer_features, columns=['Region'], drop_first=True)

# %%
# Assuming df is your DataFrame
scaler = MinMaxScaler()

# Selecting numerical columns to normalize
numerical_columns = ['TotalValue', 'Quantity', 'Price']

# Normalizing the columns
df_normalized = df.copy()
df_normalized[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# %%
# Computing similarity matrix for normalized numerical features
similarity_matrix = cosine_similarity(df_normalized[numerical_columns])

# Converting similarity matrix to a DataFrame for better readability
similarity_df = pd.DataFrame(similarity_matrix, index=df['CustomerID'], columns=df['CustomerID'])

# %%
# Filtering the first 20 customers
first_20_customers = df['CustomerID'].iloc[0:20]
lookalike_map = {}

# %%
# Getting Top 3 Lookalikes for Each Customer
def get_top_lookalikes(customer_id, similarity_df, top_n=20):
    scores = similarity_df.loc[customer_id]
    top_similar = scores.sort_values(ascending=False).iloc[1:top_n+1]
    return list(zip(top_similar.index, top_similar.values))

# %%
# Generating top 3 lookalikes for first 20 customers
lookalikes = {}
for idx, customer_id in enumerate(customer_features['CustomerID'][:20]):
    similarity_scores = list(enumerate(similarity_matrix[idx]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    top_3 = [customer_features['CustomerID'][i] for i, score in similarity_scores[1:4]]  # Exclude the customer itself
    top_3_scores = [score for i, score in similarity_scores[1:4]]
    lookalikes[customer_id] = list(zip(top_3, top_3_scores))

# %%
# Creating Lookalike.csv
lookalike_df = pd.DataFrame([
    {'CustomerID': cust_id, 'Lookalikes': lookalike_list}
    for cust_id, lookalike_list in lookalikes.items()
])
lookalike_df.to_csv('Lookalike.csv', index=False)

print("Lookalike Model generated successfully.")
# Out:
# Lookalike Model generated successfully.

# %%
lookalike_df.head(4)
# Out:
#   CustomerID                                         Lookalikes
# 0      C0001  [(C0001, 0.9999999999999999), (C0001, 0.999999...
# 1      C0002  [(C0002, 0.9999999999999999), (C0002, 0.999999...
# 2      C0003         [(C0002, 1.0), (C0003, 1.0), (C0003, 1.0)]
# 3      C0004  [(C0004, 1.0000000000000002), (C0004, 1.000000...

# %%
print(lookalike_df)
# Out:
#   CustomerID                                         Lookalikes
# 0      C0001  [(C0001, 0.9999999999999999), (C0001, 0.999999...
# 1      C0002  [(C0002, 0.9999999999999999), (C0002, 0.999999...
# 2      C0003         [(C0002, 1.0), (C0003, 1.0), (C0003, 1.0)]
# 3      C0004  [(C0004, 1.0000000000000002), (C0004, 1.000000...
